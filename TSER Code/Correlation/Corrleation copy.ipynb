# %%
import numpy as np
import pickle
import pandas as pd

# %%
# Load the Correlation:
dict_path = '/home/sim/Desktop/TS Extrinsic Regression/TSER Code/Correlation/correlations_agluon.pkl'
with open(dict_path, 'rb') as file:
    correlations = pickle.load(file)

# %%
# Get Average Correlation of absolute value over each (ds_name, tq)
# The Entries are Series object, the row name is the featuer name!


ds_names = [
    'BenzeneConcentration',
    'BeijingPM25Quality',
    'FloodModeling1',
    'BeijingPM10Quality',
    'HouseholdPowerConsumption1',
    'IEEEPPG',
    'Covid3Month',
    'AppliancesEnergy',

]
dropout_values = [None, 0.5, 0.75, 0.85, 0.9, 0.95, 0.97, 0.99]
tqs = ['dct', 'dft', 'dwt']



corr_ds_name_tq = {}
for ds_name in ds_names:
    for tq in tqs:

        avg_corr = correlations[(ds_name,tq,0.5)].abs()
        for d_val in dropout_values[2:]:
            curr_corr_df = correlations[(ds_name,tq,d_val)].abs()  # take abs value
            avg_corr = curr_corr_df + avg_corr
        
        avg_corr = avg_corr / (len(dropout_values)-1 )
        corr_ds_name_tq[(ds_name, tq)] = avg_corr.sort_values(ascending=False)



corr_ds_name = {}
for ds_name in ds_names:
    corr_ds_name[ds_name] = corr_ds_name_tq[(ds_name, 'dct')] + corr_ds_name_tq[(ds_name, 'dft')] + corr_ds_name_tq[(ds_name, 'dwt')]

    corr_ds_name[ds_name] = corr_ds_name[ds_name].sort_values(ascending=False) / 3

# %%
# Get Correlation over each dataset

for ds_name in ds_names:
    print(ds_name )
    print(corr_ds_name[(ds_name)].head(10))
    print()
# Out:
# BenzeneConcentration
# prediction                                                          1.000000
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.574533
# dim_2__mean_change                                                  0.574533
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.516657
# dim_1__mean_change                                                  0.516657
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.516147
# dim_4__mean_change                                                  0.516147
# dim_5__mean_change                                                  0.485008
# dim_5__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.485008
# dim_3__mean_change                                                  0.477056
# dtype: float64
#
# BeijingPM25Quality
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.507587
# dim_3__ratio_value_number_to_time_series_length                  0.507518
# dim_3__lempel_ziv_complexity__bins_100                           0.451742
# dim_3__percentage_of_reoccurring_values_to_all_values            0.442397
# dim_3__binned_entropy__max_bins_10                               0.295976
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.268891
# dim_3__lempel_ziv_complexity__bins_10                            0.256889
# dim_1__ratio_value_number_to_time_series_length                  0.233175
# dim_3__has_duplicate_min                                         0.223432
# dtype: float64
#
# FloodModeling1
# prediction                                                         1.000000
# dim_1__sum_of_reoccurring_data_points                              0.308223
# dim_1__number_crossing_m__m_1                                      0.299324
# dim_1__mean_abs_change                                             0.299018
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0    0.299018
# dim_1__absolute_sum_of_changes                                     0.299018
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.295197
# dim_1__fft_aggregated__aggtype_variance                            0.294697
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.290605
# dim_1__fft_aggregated__aggtype_centroid                            0.286673
# dtype: float64
#
# BeijingPM10Quality
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.417761
# dim_3__ratio_value_number_to_time_series_length                  0.413805
# dim_3__lempel_ziv_complexity__bins_100                           0.361633
# dim_3__percentage_of_reoccurring_values_to_all_values            0.359977
# dim_3__binned_entropy__max_bins_10                               0.241928
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.240141
# dim_1__ratio_value_number_to_time_series_length                  0.215384
# dim_3__lempel_ziv_complexity__bins_10                            0.210763
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.199765
# dtype: float64
#
# HouseholdPowerConsumption1
# prediction                                                       1.000000
# dim_2__ratio_value_number_to_time_series_length                  0.203704
# dim_5__sum_of_reoccurring_values                                 0.181685
# dim_2__lempel_ziv_complexity__bins_10                            0.181655
# dim_2__binned_entropy__max_bins_10                               0.177297
# dim_2__sum_of_reoccurring_values                                 0.170689
# dim_5__cid_ce__normalize_False                                   0.168219
# dim_5__cid_ce__normalize_True                                    0.167658
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.166537
# dim_5__autocorrelation__lag_2                                    0.166068
# dtype: float64
#
# IEEEPPG
# prediction                                           1.000000
# dim_1__abs_energy                                    0.304705
# dim_1__variance                                      0.304610
# dim_1__root_mean_square                              0.304479
# dim_1__standard_deviation                            0.304396
# dim_1__linear_trend__attr_stderr                     0.303132
# dim_1__agg_autocorrelation__f_agg_mean__maxlag_40    0.289541
# dim_2__abs_energy                                    0.286869
# dim_2__variance                                      0.286720
# dim_2__root_mean_square                              0.285191
# dtype: float64
#
# Covid3Month
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.377816
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.377816
# dim_1__fft_coefficient__attr_real__coeff_28                         0.271072
# dim_1__fft_coefficient__attr_imag__coeff_23                         0.268208
# dim_1__fft_coefficient__attr_imag__coeff_25                         0.260861
# dim_1__fft_coefficient__attr_imag__coeff_24                         0.257940
# dim_1__fft_coefficient__attr_imag__coeff_11                         0.255838
# dim_1__fft_coefficient__attr_imag__coeff_26                         0.255440
# dim_1__fft_coefficient__attr_real__coeff_27                         0.254739
# dtype: float64
#
# AppliancesEnergy
# prediction                                                        1.000000
# dim_5__ratio_value_number_to_time_series_length                   0.552393
# dim_5__lempel_ziv_complexity__bins_100                            0.496301
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints     0.483901
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints     0.456098
# dim_6__ratio_value_number_to_time_series_length                   0.448908
# dim_11__fft_coefficient__attr_imag__coeff_62                      0.447683
# dim_3__fft_coefficient__attr_imag__coeff_64                       0.439648
# dim_5__percentage_of_reoccurring_values_to_all_values             0.423687
# dim_14__percentage_of_reoccurring_datapoints_to_all_datapoints    0.420263
# dtype: float64

# %%
# Get Correlation over all (dataset, tq)  
for ds_name in ds_names:
    for tq in tqs:
        print(ds_name + " " + tq)
        print(corr_ds_name_tq[(ds_name, tq)].head(10))
        print()
# Out:
# BenzeneConcentration dct
# prediction                                                          1.000000
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.576548
# dim_2__mean_change                                                  0.576548
# dim_4__mean_change                                                  0.531188
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.531188
# dim_1__mean_change                                                  0.527808
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.527808
# dim_5__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.495580
# dim_5__mean_change                                                  0.495580
# dim_3__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.482378
# dtype: float64
#
# BenzeneConcentration dft
# prediction                                                          1.000000
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.607321
# dim_2__mean_change                                                  0.607321
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.561180
# dim_1__mean_change                                                  0.561180
# dim_4__mean_change                                                  0.561033
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.561033
# dim_5__mean_change                                                  0.532145
# dim_5__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.532145
# dim_3__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.506652
# dtype: float64
#
# BenzeneConcentration dwt
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.539729
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.539729
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.460982
# dim_1__mean_change                                                  0.460982
# dim_4__mean_change                                                  0.456220
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.456220
# dim_3__mean_change                                                  0.442137
# dim_3__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.442137
# dim_5__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.427299
# dtype: float64
#
# BeijingPM25Quality dct
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.510654
# dim_3__ratio_value_number_to_time_series_length                  0.507547
# dim_3__lempel_ziv_complexity__bins_100                           0.453926
# dim_3__percentage_of_reoccurring_values_to_all_values            0.438306
# dim_3__binned_entropy__max_bins_10                               0.305412
# dim_3__lempel_ziv_complexity__bins_10                            0.266910
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.263672
# dim_3__has_duplicate_min                                         0.225279
# dim_1__ratio_value_number_to_time_series_length                  0.218496
# dtype: float64
#
# BeijingPM25Quality dft
# prediction                                                         1.000000
# dim_3__ratio_value_number_to_time_series_length                    0.505241
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints      0.503564
# dim_3__lempel_ziv_complexity__bins_100                             0.450699
# dim_3__percentage_of_reoccurring_values_to_all_values              0.434961
# dim_3__binned_entropy__max_bins_10                                 0.302639
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints      0.268714
# dim_3__lempel_ziv_complexity__bins_10                              0.263606
# dim_4__change_quantiles__f_agg_mean__isabs_True__qh_0.4__ql_0.0    0.225994
# dim_1__ratio_value_number_to_time_series_length                    0.224534
# dtype: float64
#
# BeijingPM25Quality dwt
# prediction                                                       1.000000
# dim_3__ratio_value_number_to_time_series_length                  0.509767
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.508543
# dim_3__percentage_of_reoccurring_values_to_all_values            0.453923
# dim_3__lempel_ziv_complexity__bins_100                           0.450601
# dim_3__binned_entropy__max_bins_10                               0.279878
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.274287
# dim_1__ratio_value_number_to_time_series_length                  0.256494
# dim_3__lempel_ziv_complexity__bins_10                            0.240152
# dim_3__number_peaks__n_1                                         0.231329
# dtype: float64
#
# FloodModeling1 dct
# prediction                                                         1.000000
# dim_1__sum_of_reoccurring_data_points                              0.380607
# dim_1__mean_abs_change                                             0.363864
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0    0.363864
# dim_1__absolute_sum_of_changes                                     0.363864
# dim_1__number_crossing_m__m_1                                      0.360597
# dim_1__fft_aggregated__aggtype_variance                            0.355058
# dim_1__fft_aggregated__aggtype_centroid                            0.343709
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.343437
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.335066
# dtype: float64
#
# FloodModeling1 dft
# prediction                                                         1.000000
# dim_1__sum_of_reoccurring_data_points                              0.373530
# dim_1__fft_aggregated__aggtype_variance                            0.361908
# dim_1__number_crossing_m__m_1                                      0.356225
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0    0.354613
# dim_1__mean_abs_change                                             0.354613
# dim_1__absolute_sum_of_changes                                     0.354613
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.344728
# dim_1__fft_aggregated__aggtype_centroid                            0.332235
# dim_1__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_var      0.331519
# dtype: float64
#
# FloodModeling1 dwt
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4     0.245045
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.4      0.240885
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2     0.213036
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4     0.208015
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2     0.197427
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.2      0.196987
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     0.194828
# dim_1__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_max    0.194560
# dim_1__agg_linear_trend__attr_slope__chunk_len_5__f_agg_max         0.185423
# dtype: float64
#
# BeijingPM10Quality dct
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.408546
# dim_3__ratio_value_number_to_time_series_length                  0.402271
# dim_3__lempel_ziv_complexity__bins_100                           0.356676
# dim_3__percentage_of_reoccurring_values_to_all_values            0.347372
# dim_3__binned_entropy__max_bins_10                               0.246293
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.223615
# dim_3__lempel_ziv_complexity__bins_10                            0.216918
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.194787
# dim_1__ratio_value_number_to_time_series_length                  0.192930
# dtype: float64
#
# BeijingPM10Quality dft
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.439146
# dim_3__ratio_value_number_to_time_series_length                  0.434776
# dim_3__lempel_ziv_complexity__bins_100                           0.382629
# dim_3__percentage_of_reoccurring_values_to_all_values            0.377517
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.261702
# dim_3__binned_entropy__max_bins_10                               0.260663
# dim_1__ratio_value_number_to_time_series_length                  0.233737
# dim_3__lempel_ziv_complexity__bins_10                            0.228041
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.212551
# dtype: float64
#
# BeijingPM10Quality dwt
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.405592
# dim_3__ratio_value_number_to_time_series_length                  0.404370
# dim_3__percentage_of_reoccurring_values_to_all_values            0.355043
# dim_3__lempel_ziv_complexity__bins_100                           0.345595
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.235106
# dim_1__ratio_value_number_to_time_series_length                  0.219484
# dim_3__binned_entropy__max_bins_10                               0.218829
# dim_3__number_peaks__n_1                                         0.204458
# dim_1__percentage_of_reoccurring_values_to_all_values            0.201772
# dtype: float64
#
# HouseholdPowerConsumption1 dct
# prediction                                         1.000000
# dim_2__ratio_value_number_to_time_series_length    0.196615
# dim_5__sum_of_reoccurring_values                   0.194262
# dim_5__cid_ce__normalize_False                     0.184271
# dim_5__cid_ce__normalize_True                      0.184046
# dim_2__binned_entropy__max_bins_10                 0.181930
# dim_5__autocorrelation__lag_3                      0.179403
# dim_5__abs_energy                                  0.177493
# dim_5__variance                                    0.177493
# dim_5__autocorrelation__lag_4                      0.177470
# dtype: float64
#
# HouseholdPowerConsumption1 dft
# prediction                                                         1.000000
# dim_5__cid_ce__normalize_True                                      0.220534
# dim_5__autocorrelation__lag_7                                      0.219689
# dim_5__cid_ce__normalize_False                                     0.219010
# dim_5__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.6    0.217579
# dim_5__sum_of_reoccurring_values                                   0.217352
# dim_5__autocorrelation__lag_3                                      0.216873
# dim_5__autocorrelation__lag_4                                      0.215282
# dim_5__autocorrelation__lag_6                                      0.213594
# dim_5__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2    0.213113
# dtype: float64
#
# HouseholdPowerConsumption1 dwt
# prediction                                                         1.000000
# dim_2__ratio_value_number_to_time_series_length                    0.263943
# dim_2__lempel_ziv_complexity__bins_10                              0.227471
# dim_2__sum_of_reoccurring_values                                   0.220781
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints      0.216425
# dim_4__change_quantiles__f_agg_var__isabs_False__qh_0.4__ql_0.0    0.192305
# dim_5__ratio_value_number_to_time_series_length                    0.188732
# dim_4__change_quantiles__f_agg_var__isabs_True__qh_0.4__ql_0.0     0.184442
# dim_2__binned_entropy__max_bins_10                                 0.184229
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints      0.183493
# dtype: float64
#
# IEEEPPG dct
# prediction                                           1.000000
# dim_1__abs_energy                                    0.304876
# dim_1__variance                                      0.304876
# dim_1__standard_deviation                            0.304739
# dim_1__root_mean_square                              0.304739
# dim_1__linear_trend__attr_stderr                     0.303529
# dim_2__agg_autocorrelation__f_agg_mean__maxlag_40    0.292035
# dim_2__autocorrelation__lag_9                        0.291126
# dim_1__autocorrelation__lag_9                        0.291063
# dim_2__autocorrelation__lag_8                        0.288530
# dtype: float64
#
# IEEEPPG dft
# prediction                                                        1.000000
# dim_1__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_max      0.318162
# dim_1__standard_deviation                                         0.310119
# dim_1__root_mean_square                                           0.310119
# dim_1__abs_energy                                                 0.309929
# dim_1__variance                                                   0.309929
# dim_1__linear_trend__attr_stderr                                  0.308224
# dim_2__agg_autocorrelation__f_agg_mean__maxlag_40                 0.303246
# dim_1__agg_autocorrelation__f_agg_mean__maxlag_40                 0.297459
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.8    0.295420
# dtype: float64
#
# IEEEPPG dwt
# prediction                                        1.000000
# dim_1__fft_aggregated__aggtype_kurtosis           0.306236
# dim_2__abs_energy                                 0.302875
# dim_2__variance                                   0.302428
# dim_1__permutation_entropy__dimension_3__tau_1    0.301831
# dim_2__linear_trend__attr_stderr                  0.300942
# dim_2__root_mean_square                           0.300556
# dim_2__standard_deviation                         0.300140
# dim_1__abs_energy                                 0.299311
# dim_1__variance                                   0.299024
# dtype: float64
#
# Covid3Month dct
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.460915
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.460915
# dim_1__fft_coefficient__attr_imag__coeff_23                         0.328309
# dim_1__fft_coefficient__attr_real__coeff_28                         0.313709
# dim_1__fft_coefficient__attr_imag__coeff_26                         0.312381
# dim_1__fft_coefficient__attr_real__coeff_29                         0.309679
# dim_1__fft_coefficient__attr_real__coeff_27                         0.282292
# dim_1__fft_coefficient__attr_imag__coeff_11                         0.280555
# dim_1__fft_coefficient__attr_imag__coeff_25                         0.268523
# dtype: float64
#
# Covid3Month dft
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.462541
# dim_1__mean_change                                                  0.462541
# dim_1__fft_coefficient__attr_imag__coeff_23                         0.384656
# dim_1__fft_coefficient__attr_imag__coeff_25                         0.370188
# dim_1__fft_coefficient__attr_imag__coeff_24                         0.369657
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.357079
# dim_1__fft_coefficient__attr_imag__coeff_11                         0.354529
# dim_1__fft_coefficient__attr_real__coeff_28                         0.346067
# dim_1__fft_coefficient__attr_imag__coeff_26                         0.331837
# dtype: float64
#
# Covid3Month dwt
# prediction                                                         1.000000
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.2     0.291222
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2    0.283832
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.8     0.273433
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.270373
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.4     0.269865
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.8    0.263199
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4    0.262662
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.8    0.260283
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_0.4__ql_0.0    0.259331
# dtype: float64
#
# AppliancesEnergy dct
# prediction                                                        1.000000
# dim_5__ratio_value_number_to_time_series_length                   0.577721
# dim_5__lempel_ziv_complexity__bins_100                            0.540932
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints     0.502764
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints     0.472711
# dim_14__percentage_of_reoccurring_datapoints_to_all_datapoints    0.471153
# dim_6__ratio_value_number_to_time_series_length                   0.464896
# dim_14__ratio_value_number_to_time_series_length                  0.463789
# dim_11__fft_coefficient__attr_imag__coeff_62                      0.459646
# dim_14__percentage_of_reoccurring_values_to_all_values            0.444123
# dtype: float64
#
# AppliancesEnergy dft
# prediction                                                         1.000000
# dim_5__ratio_value_number_to_time_series_length                    0.574895
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints      0.510230
# dim_5__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max    0.505442
# dim_5__lempel_ziv_complexity__bins_100                             0.499444
# dim_11__fft_coefficient__attr_imag__coeff_62                       0.491331
# dim_5__agg_linear_trend__attr_slope__chunk_len_5__f_agg_max        0.474887
# dim_3__fft_coefficient__attr_imag__coeff_64                        0.474065
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints      0.464465
# dim_11__fft_coefficient__attr_real__coeff_54                       0.463354
# dtype: float64
#
# AppliancesEnergy dwt
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.504563
# dim_5__lempel_ziv_complexity__bins_100                           0.448527
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.438708
# dim_5__ar_coefficient__coeff_0__k_10                             0.435815
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints    0.431119
# dim_6__ar_coefficient__coeff_1__k_10                             0.429297
# dim_6__ratio_value_number_to_time_series_length                  0.420022
# dim_3__fft_coefficient__attr_imag__coeff_64                      0.409457
# dim_6__percentage_of_reoccurring_values_to_all_values            0.395104
# dtype: float64

# %%
# Get the Average Corr and top 5 of them per (ds_name, dval)

# Get Average Correlatin of absolute value over each (ds_name, tq)
# The Entries are Series object, the row name is the featuer name!
corr_ds_name_tq_dval = {}


for ds_name in ds_names:
    

    for dval in dropout_values[1:]:

        # Initalize a df with same columns, rows but zero in each field
        avg_corr = correlations[(ds_name,'dct', dval)].abs() + correlations[(ds_name,'dwt', dval)].abs() + correlations[(ds_name,'dft', dval)].abs()

        avg_corr = avg_corr / len(tqs)
    
        corr_ds_name_tq_dval[(ds_name, dval)] = avg_corr.sort_values(ascending=False)

# %%
# Print for Each Combination the top 5 features
for ds_name in ds_names:
    for dval in dropout_values[1:]:
        print(ds_name + " " + str(dval))
        print(corr_ds_name_tq_dval[(ds_name, dval)].head(6))
        print()
# Out:
# BenzeneConcentration 0.5
# prediction                                                          1.000000
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.415523
# dim_2__mean_change                                                  0.415523
# dim_3__mean_change                                                  0.338760
# dim_3__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.338760
# dim_1__mean_change                                                  0.312119
# dtype: float64
#
# BenzeneConcentration 0.75
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.551188
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.551188
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.479063
# dim_4__mean_change                                                  0.479063
# dim_1__mean_change                                                  0.473033
# dtype: float64
#
# BenzeneConcentration 0.85
# prediction                                                          1.000000
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.569310
# dim_2__mean_change                                                  0.569310
# dim_4__mean_change                                                  0.512972
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.512972
# dim_1__mean_change                                                  0.508324
# dtype: float64
#
# BenzeneConcentration 0.9
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.587813
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.587813
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.537950
# dim_1__mean_change                                                  0.537950
# dim_4__mean_change                                                  0.536821
# dtype: float64
#
# BenzeneConcentration 0.95
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.621059
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.621059
# dim_1__mean_change                                                  0.584982
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.584982
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.579270
# dtype: float64
#
# BenzeneConcentration 0.97
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.629973
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.629973
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.594740
# dim_1__mean_change                                                  0.594740
# dim_4__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.590495
# dtype: float64
#
# BenzeneConcentration 0.99
# prediction                                                          1.000000
# dim_2__mean_change                                                  0.646863
# dim_2__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.646863
# dim_1__mean_change                                                  0.605451
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.605451
# dim_4__mean_change                                                  0.602934
# dtype: float64
#
# BeijingPM25Quality 0.5
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.495787
# dim_3__ratio_value_number_to_time_series_length                  0.469133
# dim_3__percentage_of_reoccurring_values_to_all_values            0.445721
# dim_3__lempel_ziv_complexity__bins_100                           0.439603
# dim_3__binned_entropy__max_bins_10                               0.283697
# dtype: float64
#
# BeijingPM25Quality 0.75
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.504477
# dim_3__ratio_value_number_to_time_series_length                  0.491975
# dim_3__percentage_of_reoccurring_values_to_all_values            0.453365
# dim_3__lempel_ziv_complexity__bins_100                           0.446747
# dim_3__binned_entropy__max_bins_10                               0.300895
# dtype: float64
#
# BeijingPM25Quality 0.85
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.487376
# dim_3__ratio_value_number_to_time_series_length                  0.476906
# dim_3__percentage_of_reoccurring_values_to_all_values            0.430085
# dim_3__lempel_ziv_complexity__bins_100                           0.427515
# dim_3__binned_entropy__max_bins_10                               0.275945
# dtype: float64
#
# BeijingPM25Quality 0.9
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.504376
# dim_3__ratio_value_number_to_time_series_length                  0.499352
# dim_3__lempel_ziv_complexity__bins_100                           0.442170
# dim_3__percentage_of_reoccurring_values_to_all_values            0.436165
# dim_3__binned_entropy__max_bins_10                               0.278510
# dtype: float64
#
# BeijingPM25Quality 0.95
# prediction                                                       1.000000
# dim_3__ratio_value_number_to_time_series_length                  0.538726
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.531734
# dim_3__lempel_ziv_complexity__bins_100                           0.469021
# dim_3__percentage_of_reoccurring_values_to_all_values            0.447940
# dim_3__binned_entropy__max_bins_10                               0.302537
# dtype: float64
#
# BeijingPM25Quality 0.97
# prediction                                                       1.000000
# dim_3__ratio_value_number_to_time_series_length                  0.567835
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.549203
# dim_3__lempel_ziv_complexity__bins_100                           0.490023
# dim_3__percentage_of_reoccurring_values_to_all_values            0.460411
# dim_3__binned_entropy__max_bins_10                               0.322689
# dtype: float64
#
# BeijingPM25Quality 0.99
# prediction                                                         1.000000
# dim_3__ratio_value_number_to_time_series_length                    0.508700
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints      0.480156
# dim_3__lempel_ziv_complexity__bins_100                             0.447117
# dim_3__percentage_of_reoccurring_values_to_all_values              0.423091
# dim_4__change_quantiles__f_agg_mean__isabs_True__qh_0.6__ql_0.0    0.356270
# dtype: float64
#
# FloodModeling1 0.5
# prediction                                                       1.000000
# dim_1__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_var    0.176615
# dim_1__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_var    0.173344
# dim_1__sum_of_reoccurring_data_points                            0.172688
# dim_1__fft_coefficient__attr_imag__coeff_24                      0.158723
# dim_1__percentage_of_reoccurring_values_to_all_values            0.154511
# dtype: float64
#
# FloodModeling1 0.75
# prediction                                                         1.000000
# dim_1__fft_coefficient__attr_angle__coeff_0                        0.222641
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.207880
# dim_1__sum_of_reoccurring_data_points                              0.200465
# dim_1__mean_abs_change                                             0.196902
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0    0.196902
# dtype: float64
#
# FloodModeling1 0.85
# prediction                                                         1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0    0.285166
# dim_1__mean_abs_change                                             0.285166
# dim_1__absolute_sum_of_changes                                     0.285166
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.278881
# dim_1__sum_of_reoccurring_data_points                              0.272028
# dtype: float64
#
# FloodModeling1 0.9
# prediction                                                         1.000000
# dim_1__number_crossing_m__m_1                                      0.392836
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.390754
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.384184
# dim_1__absolute_sum_of_changes                                     0.378436
# dim_1__mean_abs_change                                             0.378436
# dtype: float64
#
# FloodModeling1 0.95
# prediction                                                       1.000000
# dim_1__fft_aggregated__aggtype_variance                          0.401907
# dim_1__agg_linear_trend__attr_rvalue__chunk_len_5__f_agg_max     0.385701
# dim_1__agg_linear_trend__attr_rvalue__chunk_len_10__f_agg_max    0.383386
# dim_1__sum_of_reoccurring_data_points                            0.382639
# dim_1__fft_aggregated__aggtype_centroid                          0.367764
# dtype: float64
#
# FloodModeling1 0.97
# prediction                                 1.000000
# dim_1__c3__lag_1                           0.452290
# dim_1__ar_coefficient__coeff_1__k_10       0.432797
# dim_1__number_crossing_m__m_1              0.431046
# dim_1__fft_aggregated__aggtype_variance    0.407445
# dim_1__fft_aggregated__aggtype_centroid    0.407033
# dtype: float64
#
# FloodModeling1 0.99
# prediction                                                         1.000000
# dim_1__c3__lag_1                                                   0.502720
# dim_1__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_var      0.477426
# dim_1__sum_of_reoccurring_data_points                              0.420263
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max    0.410145
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.409063
# dtype: float64
#
# BeijingPM10Quality 0.5
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.421109
# dim_3__ratio_value_number_to_time_series_length                  0.399675
# dim_3__percentage_of_reoccurring_values_to_all_values            0.357358
# dim_3__lempel_ziv_complexity__bins_100                           0.355639
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.235085
# dtype: float64
#
# BeijingPM10Quality 0.75
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.388695
# dim_3__ratio_value_number_to_time_series_length                  0.375521
# dim_3__percentage_of_reoccurring_values_to_all_values            0.341298
# dim_3__lempel_ziv_complexity__bins_100                           0.323335
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.221908
# dtype: float64
#
# BeijingPM10Quality 0.85
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.382638
# dim_3__ratio_value_number_to_time_series_length                  0.370681
# dim_3__percentage_of_reoccurring_values_to_all_values            0.333636
# dim_3__lempel_ziv_complexity__bins_100                           0.326965
# dim_3__binned_entropy__max_bins_10                               0.220590
# dtype: float64
#
# BeijingPM10Quality 0.9
# prediction                                                       1.000000
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.378966
# dim_3__ratio_value_number_to_time_series_length                  0.369393
# dim_3__lempel_ziv_complexity__bins_100                           0.330162
# dim_3__percentage_of_reoccurring_values_to_all_values            0.325585
# dim_3__binned_entropy__max_bins_10                               0.216988
# dtype: float64
#
# BeijingPM10Quality 0.95
# prediction                                                       1.000000
# dim_3__ratio_value_number_to_time_series_length                  0.440210
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.438890
# dim_3__lempel_ziv_complexity__bins_100                           0.381391
# dim_3__percentage_of_reoccurring_values_to_all_values            0.367086
# dim_3__binned_entropy__max_bins_10                               0.258205
# dtype: float64
#
# BeijingPM10Quality 0.97
# prediction                                                       1.000000
# dim_3__ratio_value_number_to_time_series_length                  0.489892
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints    0.480193
# dim_3__lempel_ziv_complexity__bins_100                           0.421496
# dim_3__percentage_of_reoccurring_values_to_all_values            0.407060
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints    0.291833
# dtype: float64
#
# BeijingPM10Quality 0.99
# prediction                                                         1.000000
# dim_3__ratio_value_number_to_time_series_length                    0.451266
# dim_3__percentage_of_reoccurring_datapoints_to_all_datapoints      0.433839
# dim_3__lempel_ziv_complexity__bins_100                             0.392445
# dim_3__percentage_of_reoccurring_values_to_all_values              0.387818
# dim_4__change_quantiles__f_agg_mean__isabs_True__qh_0.6__ql_0.0    0.313749
# dtype: float64
#
# HouseholdPowerConsumption1 0.5
# prediction                                                         1.000000
# dim_2__change_quantiles__f_agg_var__isabs_False__qh_0.2__ql_0.0    0.247944
# dim_2__change_quantiles__f_agg_var__isabs_True__qh_0.2__ql_0.0     0.244837
# dim_2__change_quantiles__f_agg_var__isabs_False__qh_0.4__ql_0.0    0.232020
# dim_2__change_quantiles__f_agg_var__isabs_True__qh_0.4__ql_0.0     0.230904
# dim_2__ratio_value_number_to_time_series_length                    0.230098
# dtype: float64
#
# HouseholdPowerConsumption1 0.75
# prediction                                                         1.000000
# dim_2__ratio_value_number_to_time_series_length                    0.212235
# dim_4__change_quantiles__f_agg_mean__isabs_True__qh_0.4__ql_0.0    0.200933
# dim_4__number_crossing_m__m_-1                                     0.189369
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints      0.188114
# dim_4__agg_autocorrelation__f_agg_var__maxlag_40                   0.184329
# dtype: float64
#
# HouseholdPowerConsumption1 0.85
# prediction                                                       1.000000
# dim_2__ratio_value_number_to_time_series_length                  0.252940
# dim_2__sum_of_reoccurring_values                                 0.217711
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.197916
# dim_2__permutation_entropy__dimension_7__tau_1                   0.197139
# dim_2__permutation_entropy__dimension_3__tau_1                   0.194479
# dtype: float64
#
# HouseholdPowerConsumption1 0.9
# prediction                                                       1.000000
# dim_2__ratio_value_number_to_time_series_length                  0.256611
# dim_2__sum_of_reoccurring_values                                 0.224649
# dim_2__lempel_ziv_complexity__bins_10                            0.220101
# dim_2__binned_entropy__max_bins_10                               0.198673
# dim_2__percentage_of_reoccurring_datapoints_to_all_datapoints    0.197720
# dtype: float64
#
# HouseholdPowerConsumption1 0.95
# prediction                                         1.000000
# dim_2__lempel_ziv_complexity__bins_10              0.228704
# dim_2__ratio_value_number_to_time_series_length    0.223097
# dim_2__binned_entropy__max_bins_10                 0.220900
# dim_2__lempel_ziv_complexity__bins_3               0.208152
# dim_2__sum_of_reoccurring_values                   0.181589
# dtype: float64
#
# HouseholdPowerConsumption1 0.97
# prediction                                                         1.000000
# dim_4__symmetry_looking__r_0.4                                     0.307347
# dim_4__large_standard_deviation__r_0.45                            0.307347
# dim_4__symmetry_looking__r_0.35000000000000003                     0.307347
# dim_4__change_quantiles__f_agg_var__isabs_False__qh_0.6__ql_0.4    0.305712
# dim_4__change_quantiles__f_agg_var__isabs_False__qh_0.6__ql_0.2    0.305423
# dtype: float64
#
# HouseholdPowerConsumption1 0.99
# prediction                                                         1.000000
# dim_5__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.6     0.376847
# dim_5__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.6    0.375777
# dim_5__autocorrelation__lag_8                                      0.365075
# dim_5__sum_of_reoccurring_values                                   0.364751
# dim_5__autocorrelation__lag_7                                      0.364126
# dtype: float64
#
# IEEEPPG 0.5
# prediction                                                         1.000000
# dim_1__autocorrelation__lag_2                                      0.383836
# dim_1__partial_autocorrelation__lag_1                              0.381594
# dim_1__autocorrelation__lag_1                                      0.381594
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.0    0.377635
# dim_1__autocorrelation__lag_4                                      0.372784
# dtype: float64
#
# IEEEPPG 0.75
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.492428
# dim_4__ratio_value_number_to_time_series_length                  0.476230
# dim_3__ratio_value_number_to_time_series_length                  0.474893
# dim_1__agg_autocorrelation__f_agg_mean__maxlag_40                0.420906
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.414552
# dtype: float64
#
# IEEEPPG 0.85
# prediction                                           1.000000
# dim_5__ratio_value_number_to_time_series_length      0.506248
# dim_3__ratio_value_number_to_time_series_length      0.479964
# dim_1__agg_autocorrelation__f_agg_mean__maxlag_40    0.474998
# dim_4__ratio_value_number_to_time_series_length      0.447205
# dim_2__agg_autocorrelation__f_agg_mean__maxlag_40    0.435642
# dtype: float64
#
# IEEEPPG 0.9
# prediction                                                         1.000000
# dim_1__agg_autocorrelation__f_agg_mean__maxlag_40                  0.450150
# dim_1__autocorrelation__lag_9                                      0.432115
# dim_2__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.427934
# dim_2__autocorrelation__lag_9                                      0.427180
# dim_2__change_quantiles__f_agg_mean__isabs_True__qh_0.8__ql_0.2    0.426530
# dtype: float64
#
# IEEEPPG 0.95
# prediction                                                       1.000000
# dim_1__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_max     0.355633
# dim_1__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_max    0.319329
# dim_2__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_mean    0.309554
# dim_1__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_mean    0.307439
# dim_1__friedrich_coefficients__coeff_3__m_3__r_30                0.305580
# dtype: float64
#
# IEEEPPG 0.97
# prediction                                                       1.000000
# dim_3__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_mean    0.339029
# dim_3__ar_coefficient__coeff_1__k_10                             0.332057
# dim_1__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_max     0.325528
# dim_3__percentage_of_reoccurring_values_to_all_values            0.321907
# dim_3__permutation_entropy__dimension_7__tau_1                   0.316277
# dtype: float64
#
# IEEEPPG 0.99
# prediction                                        1.000000
# dim_3__number_peaks__n_3                          0.406725
# dim_3__permutation_entropy__dimension_7__tau_1    0.391994
# dim_3__permutation_entropy__dimension_6__tau_1    0.386784
# dim_3__permutation_entropy__dimension_5__tau_1    0.379360
# dim_3__number_peaks__n_1                          0.374843
# dtype: float64
#
# Covid3Month 0.5
# prediction                                                    1.000000
# dim_1__fft_aggregated__aggtype_kurtosis                       0.316678
# dim_1__cwt_coefficients__coeff_12__w_2__widths_(2 5 10 20)    0.312593
# dim_1__fft_coefficient__attr_abs__coeff_1                     0.288851
# dim_1__fft_coefficient__attr_abs__coeff_11                    0.271104
# dim_1__cwt_coefficients__coeff_11__w_2__widths_(2 5 10 20)    0.267813
# dtype: float64
#
# Covid3Month 0.75
# prediction                                                         1.000000
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.4     0.344322
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.339363
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4    0.338694
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2    0.301201
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.299741
# dtype: float64
#
# Covid3Month 0.85
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.389685
# dim_1__mean_change                                                  0.389685
# dim_1__fft_coefficient__attr_real__coeff_29                         0.353665
# dim_1__cwt_coefficients__coeff_1__w_2__widths_(2 5 10 20)           0.335895
# dim_1__partial_autocorrelation__lag_2                               0.291166
# dtype: float64
#
# Covid3Month 0.9
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.394382
# dim_1__mean_change                                                  0.394382
# dim_1__fft_coefficient__attr_real__coeff_42                         0.298815
# dim_1__fft_coefficient__attr_real__coeff_4                          0.297888
# dim_1__fft_coefficient__attr_imag__coeff_25                         0.296621
# dtype: float64
#
# Covid3Month 0.95
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.427634
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.427634
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.396676
# dim_1__fft_coefficient__attr_imag__coeff_25                         0.348071
# dim_1__fft_coefficient__attr_imag__coeff_26                         0.344873
# dtype: float64
#
# Covid3Month 0.97
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.473891
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.473891
# dim_1__fft_coefficient__attr_imag__coeff_26                         0.414888
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.399301
# dim_1__fft_coefficient__attr_imag__coeff_24                         0.396344
# dtype: float64
#
# Covid3Month 0.99
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.6    0.460005
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.449067
# dim_1__mean_change                                                  0.443639
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.443639
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.4    0.419450
# dtype: float64
#
# AppliancesEnergy 0.5
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.489407
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints    0.452239
# dim_6__ratio_value_number_to_time_series_length                  0.442357
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.436840
# dim_8__ar_coefficient__coeff_7__k_10                             0.425888
# dtype: float64
#
# AppliancesEnergy 0.75
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.571872
# dim_11__fft_coefficient__attr_imag__coeff_62                     0.547318
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.520007
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints    0.503755
# dim_6__ratio_value_number_to_time_series_length                  0.494215
# dtype: float64
#
# AppliancesEnergy 0.85
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.612196
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.555815
# dim_11__fft_coefficient__attr_imag__coeff_62                     0.546308
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints    0.528186
# dim_18__permutation_entropy__dimension_3__tau_1                  0.505150
# dtype: float64
#
# AppliancesEnergy 0.9
# prediction                                                       1.000000
# dim_5__ratio_value_number_to_time_series_length                  0.606261
# dim_5__percentage_of_reoccurring_datapoints_to_all_datapoints    0.529259
# dim_5__lempel_ziv_complexity__bins_100                           0.520502
# dim_6__percentage_of_reoccurring_datapoints_to_all_datapoints    0.519395
# dim_5__ar_coefficient__coeff_1__k_10                             0.517376
# dtype: float64
#
# AppliancesEnergy 0.95
# prediction                                         1.000000
# dim_5__ar_coefficient__coeff_1__k_10               0.625864
# dim_6__ar_coefficient__coeff_1__k_10               0.560915
# dim_5__ratio_value_number_to_time_series_length    0.557097
# dim_11__fft_coefficient__attr_imag__coeff_29       0.545749
# dim_5__lempel_ziv_complexity__bins_100             0.536236
# dtype: float64
#
# AppliancesEnergy 0.97
# prediction                                     1.000000
# dim_5__ar_coefficient__coeff_1__k_10           0.673065
# dim_6__ar_coefficient__coeff_1__k_10           0.665873
# dim_3__fft_coefficient__attr_imag__coeff_64    0.571694
# dim_5__fft_coefficient__attr_imag__coeff_14    0.564627
# dim_5__lempel_ziv_complexity__bins_100         0.564459
# dtype: float64
#
# AppliancesEnergy 0.99
# prediction                                                         1.000000
# dim_6__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.8    0.656925
# dim_6__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.8    0.652140
# dim_6__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.2     0.612590
# dim_6__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2    0.611973
# dim_6__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4    0.588076
# dtype: float64

# %%
# Print Dval over all Datasets -> Take only first dimension into account!

dval_dict = {}
for dval in dropout_values[1:]:
    print(dval)
    avg_dval = corr_ds_name_tq_dval[('AppliancesEnergy', dval)]
    avg_dval[:] = 0

    for ds_name in ds_names:
        avg_dval = avg_dval +  corr_ds_name_tq_dval[(ds_name, dval)]


    dval_dict[dval] = avg_dval.sort_values(ascending=False) / 7
    print(dval_dict[dval].head(10))
    print()
# Out:
# 0.5
# prediction                                                         1.000000
# dim_1__ratio_value_number_to_time_series_length                    0.155099
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints      0.152240
# dim_1__percentage_of_reoccurring_values_to_all_values              0.141406
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.6    0.124670
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2    0.122942
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4    0.120454
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2    0.119665
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4    0.117532
# dim_1__cid_ce__normalize_True                                      0.115389
# dtype: float64
#
# 0.75
# prediction                                                          1.000000
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints       0.155236
# dim_1__ratio_value_number_to_time_series_length                     0.152696
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2     0.149416
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4     0.144522
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4     0.142766
# dim_1__mean_change                                                  0.137837
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.137837
# dim_1__change_quantiles__f_agg_var__isabs_True__qh_1.0__ql_0.4      0.137147
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2     0.132133
# dtype: float64
#
# 0.85
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.157123
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.157123
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     0.155202
# dim_1__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_max    0.147748
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints       0.140112
# dim_1__ratio_value_number_to_time_series_length                     0.139700
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_min     0.135137
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.2     0.131796
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.0     0.129454
# dtype: float64
#
# 0.9
# prediction                                                          1.000000
# dim_1__ratio_value_number_to_time_series_length                     0.171361
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints       0.163790
# dim_1__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_max    0.161969
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.155126
# dim_1__mean_change                                                  0.155126
# dim_1__change_quantiles__f_agg_mean__isabs_True__qh_1.0__ql_0.4     0.154354
# dim_1__cid_ce__normalize_False                                      0.154172
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2     0.153261
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     0.151789
# dtype: float64
#
# 0.95
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.176845
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.176845
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.142544
# dim_1__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_max    0.137535
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     0.133733
# dim_1__ar_coefficient__coeff_1__k_10                                0.131412
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.2     0.125177
# dim_1__mean_second_derivative_central                               0.124600
# dim_1__agg_linear_trend__attr_slope__chunk_len_10__f_agg_mean       0.124088
# dtype: float64
#
# 0.97
# prediction                                                          1.000000
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.202564
# dim_1__mean_change                                                  0.202564
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.162208
# dim_1__ar_coefficient__coeff_1__k_10                                0.148461
# dim_1__percentage_of_reoccurring_datapoints_to_all_datapoints       0.146815
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.4    0.145202
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.4     0.142047
# dim_1__lempel_ziv_complexity__bins_10                               0.138568
# dim_1__range_count__max_1__min_-1                                   0.138420
# dtype: float64
#
# 0.99
# prediction                                                          1.000000
# dim_1__mean_change                                                  0.210936
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.0    0.210936
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.2    0.177424
# dim_1__permutation_entropy__dimension_3__tau_1                      0.157967
# dim_1__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_mean       0.154712
# dim_1__lempel_ziv_complexity__bins_10                               0.154007
# dim_1__change_quantiles__f_agg_mean__isabs_False__qh_1.0__ql_0.4    0.153555
# dim_1__change_quantiles__f_agg_var__isabs_False__qh_1.0__ql_0.0     0.153481
# dim_1__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     0.152707
# dtype: float64

# %% [markdown]
# FOUND OUT: For each Dataset and Technique, the number of features of tsfresh are the same! Also for each Dataset we get the same features after tsfresh for each tq and compression strength

# %%
# Code to show, that Each Datast has the same features

9 / 0
log_path = '/home/sim/Desktop/TS Extrinsic Regression/All-Logs/' 

ds_names = [
    'AppliancesEnergy',
    'NewsTitleSentiment',
    'BenzeneConcentration',
    'BeijingPM25Quality',
    'IEEEPPG',
    'FloodModeling1',
    'HouseholdPowerConsumption1',
    'Covid3Month'
]
dropout_values = [None, 0.5, 0.75, 0.85, 0.9, 0.95, 0.97, 0.99]
tqs = ['dct', 'dft', 'dwt']

common_features_dict = {}

# Helper function to find common elements in lists
def common_elements(lists):
    if not lists:
        return []
    common = lists[0]
    for lst in lists[1:]:
        common = [elem for elem in common if elem in lst]
    return common

# Iterate over them to go for each value
for ds_name in ds_names:


    for tq in tqs:
        path_to_runs = log_path + f'{ds_name}_Runs/'
        common_features = None
        features_lists = []

        
        for dval in dropout_values:
            if dval is None:
                 curr_df = pd.read_parquet('/home/sim/Desktop/TS Extrinsic Regression/features_dfs/' + ds_name + f'/NONE_NONE_{ds_name}_features_TEST')
                 features_lists.append(curr_df.columns)
                 print(len(curr_df.columns))

            else:
                curr_df = pd.read_parquet('/home/sim/Desktop/TS Extrinsic Regression/features_dfs/' + ds_name + f'/{dval}_{tq}_{ds_name}_features_TEST')
                features_lists.append(curr_df.columns)
                print(len(curr_df.columns))
            
        
        common_features = common_elements(features_lists)
        common_features_dict[(ds_name, tq)] = common_features





# Print overlapping for (Dataset,Comp_Alg) combinaton
for (ds_name, tq), common_features in common_features_dict.items():
    if common_features is not None:
        print(f"Number of overlapping features for {ds_name}: {tq} {len(common_features)}")
print()



# Print num of overlapping for each tq
overlap_per_tq = {}
for tmp_tq in tqs:
        overlap_per_tq[tmp_tq] = common_elements([common_features for (ds_name, tq), common_features in common_features_dict.items() if tq == tmp_tq])
        print(f"Number of overlapping features for whole {tmp_tq} {len(overlap_per_tq[tmp_tq])}")
print()


# Print number of overlapping for each dataset
overlapp_per_dataset = {}
for tmp_dsname in ds_names:

        overlapp_per_dataset[tmp_dsname] = common_elements([common_features for (ds_name, tq), common_features in common_features_dict.items() if ds_name == tmp_dsname])
        print(f"Number of overlapping features for whole {tmp_dsname} {len(overlapp_per_dataset[tmp_dsname])}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 # Code to show, that Each Datast has the same features
# ----> 3 9 / 0
#       4 log_path = '/home/sim/Desktop/TS Extrinsic Regression/All-Logs/'
#       6 ds_names = [
#       7     'AppliancesEnergy',
#       8     'NewsTitleSentiment',
#    (...)
#      14     'Covid3Month'
#      15 ]
#
# ZeroDivisionError: division by zero

# %%
#pd.set_option('display.max_rows', 1000)  # Show all rows
#pd.set_option('display.max_columns', 1000)  # Show all columns

# %% [markdown]
# In my loaded df are no NAN values!

# %%
# Doesnt run in VS-Code with all DS
#  Calculate the correlation, we get a dict looking like: correlations[('AppliancesEnergy', 'dft', 0.5)] -> correlation
dropout_values = [None, 0.5, 0.75, 0.85, 0.9, 0.95, 0.97, 0.99]
log_path = '/home/sim/Desktop/TS Extrinsic Regression/All-Logs/' 

ds_names = [
    'NewsTitleSentiment',
    'BenzeneConcentration',
    'BeijingPM25Quality',
    'IEEEPPG',
    'FloodModeling1',
    'HouseholdPowerConsumption1',
    'Covid3Month',
    'AppliancesEnergy',
]


tqs = ['dct', 'dft', 'dwt']

prepared_dfs = {}
correlations = {}

for ds_name in ds_names:
    path_to_runs = log_path + f'{ds_name}_Runs/'



    features_raw = pd.read_parquet('/home/sim/Desktop/TS Extrinsic Regression/features_dfs/' + ds_name + f'/NONE_NONE_{ds_name}_features_TEST').drop('target', axis=1)
    #features_raw = load_and_prepare_everything(all_ds[ds_name], None, None)[1].drop('target', axis=1)
    
    path_to_pred = path_to_runs + f'NONE_{ds_name}_20min_Flaml_f/predictions.npy'
    prediction_raw = np.load(path_to_pred)
    features_raw['prediction'] = prediction_raw


    #if features_raw.isna().any().any():
    #    print("Yes")

    for tq in tqs:



        prepared_dfs[(ds_name,tq,None)] = features_raw.copy() # bc different features for each technique

        for dval in dropout_values[1:]:
            

            features = pd.read_parquet('/home/sim/Desktop/TS Extrinsic Regression/features_dfs/' + ds_name + f'/{dval}_{tq}_{ds_name}_features_TEST').drop('target', axis=1)
            #features = load_and_prepare_everything(all_ds[ds_name], tq, dval)[1].drop('target', axis=1)
            
            path_to_pred = path_to_runs + f'{dval}_{tq}_{ds_name}_20min_Flaml_f/predictions.npy'


            prediction = np.load(path_to_pred)

            features['prediction'] = prediction
            prepared_dfs[(ds_name,tq, dval)] = features.copy()
            
            # Add Subtraction and Correlation
            sub_df = (features_raw - features)


            # Calculate the number of unique values in each column
            unique_counts = sub_df.nunique()

            # Filter out columns with only one unique value (zero variance), to avoid nan values in correlation colunm
            sub_df = sub_df.loc[:, unique_counts > 1]

            corrs = sub_df.corrwith(sub_df['prediction'])
            correlations[(ds_name,tq,dval)] = corrs

            print(f'{ds_name}, {tq}, {dval} correlation calculated')
            #print(corrs)
# Out:
# NewsTitleSentiment, dct, 0.5 correlation calculated
# NewsTitleSentiment, dct, 0.75 correlation calculated
# NewsTitleSentiment, dct, 0.85 correlation calculated
# NewsTitleSentiment, dct, 0.9 correlation calculated
# NewsTitleSentiment, dct, 0.95 correlation calculated
# NewsTitleSentiment, dct, 0.97 correlation calculated
# NewsTitleSentiment, dct, 0.99 correlation calculated
# NewsTitleSentiment, dft, 0.5 correlation calculated
# NewsTitleSentiment, dft, 0.75 correlation calculated
# NewsTitleSentiment, dft, 0.85 correlation calculated
# NewsTitleSentiment, dft, 0.9 correlation calculated
# NewsTitleSentiment, dft, 0.95 correlation calculated
# NewsTitleSentiment, dft, 0.97 correlation calculated
# NewsTitleSentiment, dft, 0.99 correlation calculated
# NewsTitleSentiment, dwt, 0.5 correlation calculated
# NewsTitleSentiment, dwt, 0.75 correlation calculated
# NewsTitleSentiment, dwt, 0.85 correlation calculated
# NewsTitleSentiment, dwt, 0.9 correlation calculated
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# To sort features

import re
def extract_fifth_number(column_name):
    match = re.match(r'^.{4}(\d+)', column_name)  # Match numbers after the first 4 characters
    if match:
        return int(match.group(1))
    return float('inf')  # Use infinity for columns without a valid number

# Create a dictionary with column names as keys and extracted numbers as values
column_sort_order = {col: extract_fifth_number(col) for col in features.columns}

# Sort columns based on the extracted numbers
sorted_columns = sorted(column_sort_order, key=column_sort_order.get)

# Reorder the DataFrame columns
features_sorted = features[sorted_columns]
features_sorted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       8     return float('inf')  # Use infinity for columns without a valid number
#      10 # Create a dictionary with column names as keys and extracted numbers as values
# ---> 11 column_sort_order = {col: extract_fifth_number(col) for col in features.columns}
#      13 # Sort columns based on the extracted numbers
#      14 sorted_columns = sorted(column_sort_order, key=column_sort_order.get)
#
# NameError: name 'features' is not defined

# %%
file_path = '/home/sim/Desktop/TS Extrinsic Regression/0.5_dct_AppliancesEnergy_20min_Flaml_f/selected_features.txt'
with open(file_path, 'r') as file:
    lines = file.readlines()

lines = [line.strip() for line in lines]

selected_features = features[lines]


column_sort_order = {col: extract_fifth_number(col) for col in selected_features.columns}

# Sort columns based on the extracted numbers
sorted_columns = sorted(column_sort_order, key=column_sort_order.get)

# Reorder the DataFrame columns
sfeatures_sorted = selected_features[sorted_columns]
sfeatures_sorted
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 file_path = '/home/sim/Desktop/TS Extrinsic Regression/0.5_dct_AppliancesEnergy_20min_Flaml_f/selected_features.txt'
# ----> 2 with open(file_path, 'r') as file:
#       3     lines = file.readlines()
#       5 lines = [line.strip() for line in lines]
#
# File ~/Desktop/TS Extrinsic Regression/.venvFlamlFwiz/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sim/Desktop/TS Extrinsic Regression/0.5_dct_AppliancesEnergy_20min_Flaml_f/selected_features.txt'
