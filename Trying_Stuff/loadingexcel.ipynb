# %%
def do_ranking(melted_df):

    def rank_accuracies(group):
        # Sort by accuracy
        sorted_group = group.sort_values('accuracy')
        # Compute ranks
        sorted_group['rank'] = sorted_group['accuracy'].rank(method='average')
        return sorted_group

    # Apply ranking within each dataset_name
    ranked_df = melted_df.groupby('dataset_name').apply(rank_accuracies).reset_index(drop=True)

    # Compute average rank per classifier
    average_rank_per_classifier = ranked_df.groupby('classifier_name')['rank'].mean().reset_index()
    average_rank_per_classifier = average_rank_per_classifier.sort_values(by='rank', ascending=True).reset_index(drop=True)

    # Extract lists
    classifier_names = average_rank_per_classifier['classifier_name'].tolist()
    average_ranks = average_rank_per_classifier['rank'].tolist()

    # Display the lists
    print("Classifier Names:", classifier_names)
    print("Average Ranks:", average_ranks)

    # Return the DataFrame sorted by average rank
    return average_rank_per_classifier

# %%
import pandas as pd

# Load the ODS file
file_path = '/home/sim/Desktop/TS Extrinsic Regression/AutoML-Results.ods'
result_df = pd.read_excel(file_path, engine='odf', sheet_name='result')

# Transform the DataFrame to have classifier names as a single column
melted_df = result_df.melt(id_vars=['Dataset Name'], var_name='classifier_name', value_name='accuracy')

# Rename columns to match the desired output
melted_df = melted_df.rename(columns={'Dataset Name': 'dataset_name'})

# Drop any rows where accuracy is NaN
melted_df = melted_df.dropna(subset=['accuracy'])

# Now melted_df contains the required data
melted_df

pd.set_option('display.max_rows', None)

# Now when you print a DataFrame, it will show all rows
print(melted_df)
# Out:
#                    dataset_name classifier_name    accuracy
# 0              AppliancesEnergy       AutoGluon    2.155978
# 1            BeijingPM10Quality       AutoGluon  108.381598
# 2            BeijingPM25Quality       AutoGluon   75.187533
# 3          BenzeneConcentration       AutoGluon    3.874767
# 4                   Covid3Month       AutoGluon    0.040439
# 5                FloodModeling1       AutoGluon    0.013680
# 6                FloodModeling2       AutoGluon    0.019079
# 7    HouseholdPowerConsumption1       AutoGluon  145.957598
# 8    HouseholdPowerConsumption2       AutoGluon   46.925185
# 9                       IEEEPPG       AutoGluon   25.574776
# 10           NewsTitleSentiment       AutoGluon    0.138126
# 11             AppliancesEnergy           FLAML    2.516904
# 12           BeijingPM10Quality           FLAML  108.381598
# 13           BeijingPM25Quality           FLAML   76.546076
# 14         BenzeneConcentration           FLAML    4.001022
# 15                  Covid3Month           FLAML    0.043481
# 16               FloodModeling1           FLAML    0.016977
# 17               FloodModeling2           FLAML    0.009305
# 18   HouseholdPowerConsumption1           FLAML  169.335060
# 19   HouseholdPowerConsumption2           FLAML   37.031474
# 20                      IEEEPPG           FLAML   27.603676
# 21           NewsTitleSentiment           FLAML    0.138103
# 22             AppliancesEnergy            FPCR    5.405052
# 23           BeijingPM10Quality            FPCR   99.725946
# 24           BeijingPM25Quality            FPCR   69.379217
# 25         BenzeneConcentration            FPCR   11.088396
# 26                  Covid3Month            FPCR    0.044912
# 27               FloodModeling1            FPCR    0.018853
# 28               FloodModeling2            FPCR    0.019079
# 29   HouseholdPowerConsumption1            FPCR  147.548998
# 30   HouseholdPowerConsumption2            FPCR   46.925185
# 31                      IEEEPPG            FPCR   31.381214
# 32           NewsTitleSentiment            FPCR    0.138126
# 33             AppliancesEnergy    FPCR-Bspline    5.405052
# 34           BeijingPM10Quality    FPCR-Bspline   99.732125
# 35           BeijingPM25Quality    FPCR-Bspline   69.369892
# 36         BenzeneConcentration    FPCR-Bspline   11.094974
# 37                  Covid3Month    FPCR-Bspline    0.044912
# 38               FloodModeling1    FPCR-Bspline    0.018853
# 39               FloodModeling2    FPCR-Bspline    0.019079
# 40   HouseholdPowerConsumption1    FPCR-Bspline  147.549200
# 41   HouseholdPowerConsumption2    FPCR-Bspline   46.929783
# 42                      IEEEPPG    FPCR-Bspline   31.381212
# 43           NewsTitleSentiment    FPCR-Bspline    0.138126
# 44             AppliancesEnergy             SVR    3.457631
# 45           BeijingPM10Quality             SVR  110.574226
# 46           BeijingPM25Quality             SVR   75.734162
# 47         BenzeneConcentration             SVR    4.790901
# 48                  Covid3Month             SVR    0.065840
# 49               FloodModeling1             SVR    0.077897
# 50               FloodModeling2             SVR    0.075804
# 51   HouseholdPowerConsumption1             SVR  519.155544
# 52   HouseholdPowerConsumption2             SVR   57.339837
# 53                      IEEEPPG             SVR   36.301933
# 54           NewsTitleSentiment             SVR    0.138881
# 55             AppliancesEnergy   SVR Optimised    3.454574
# 56           BeijingPM10Quality   SVR Optimised  110.574226
# 57           BeijingPM25Quality   SVR Optimised   71.437076
# 58         BenzeneConcentration   SVR Optimised    4.790901
# 59                  Covid3Month   SVR Optimised    0.065840
# 60               FloodModeling1   SVR Optimised    0.046304
# 61               FloodModeling2   SVR Optimised    0.075804
# 62   HouseholdPowerConsumption1   SVR Optimised  152.391358
# 63   HouseholdPowerConsumption2   SVR Optimised   55.980830
# 64                      IEEEPPG   SVR Optimised   37.254146
# 65           NewsTitleSentiment   SVR Optimised    0.138881
# 66             AppliancesEnergy   Random Forest    3.455120
# 67           BeijingPM10Quality   Random Forest   94.072344
# 68           BeijingPM25Quality   Random Forest   63.301428
# 69         BenzeneConcentration   Random Forest    0.855559
# 70                  Covid3Month   Random Forest    0.042400
# 71               FloodModeling1   Random Forest    0.015891
# 72               FloodModeling2   Random Forest    0.014095
# 73   HouseholdPowerConsumption1   Random Forest  248.858964
# 74   HouseholdPowerConsumption2   Random Forest   46.932139
# 75                      IEEEPPG   Random Forest   32.109070
# 76           NewsTitleSentiment   Random Forest    0.143103
# 77             AppliancesEnergy         XGBoost    3.489024
# 78           BeijingPM10Quality         XGBoost   93.138127
# 79           BeijingPM25Quality         XGBoost   59.495865
# 80         BenzeneConcentration         XGBoost    0.637726
# 81                  Covid3Month         XGBoost    0.044682
# 82               FloodModeling1         XGBoost    0.015971
# 83               FloodModeling2         XGBoost    0.018199
# 84   HouseholdPowerConsumption1         XGBoost  231.089829
# 85   HouseholdPowerConsumption2         XGBoost   44.372933
# 86                      IEEEPPG         XGBoost   31.487901
# 87           NewsTitleSentiment         XGBoost    0.138336
# 88             AppliancesEnergy         1-NN-ED    5.231953
# 89           BeijingPM10Quality         1-NN-ED  139.229790
# 90           BeijingPM25Quality         1-NN-ED   88.193545
# 91         BenzeneConcentration         1-NN-ED    6.535685
# 92                  Covid3Month         1-NN-ED    0.053060
# 93               FloodModeling1         1-NN-ED    0.014820
# 94               FloodModeling2         1-NN-ED    0.018552
# 95   HouseholdPowerConsumption1         1-NN-ED  473.932736
# 96   HouseholdPowerConsumption2         1-NN-ED   71.479369
# 97                      IEEEPPG         1-NN-ED   33.208862
# 98           NewsTitleSentiment         1-NN-ED    0.193318
# 99             AppliancesEnergy         5-NN-ED    4.227438
# 100          BeijingPM10Quality         5-NN-ED  115.669411
# 101          BeijingPM25Quality         5-NN-ED   74.156382
# 102        BenzeneConcentration         5-NN-ED    5.844980
# 103                 Covid3Month         5-NN-ED    0.041815
# 104              FloodModeling1         5-NN-ED    0.016193
# 105              FloodModeling2         5-NN-ED    0.018586
# 106  HouseholdPowerConsumption1         5-NN-ED  432.594707
# 107  HouseholdPowerConsumption2         5-NN-ED   64.272956
# 108                     IEEEPPG         5-NN-ED   27.111213
# 109          NewsTitleSentiment         5-NN-ED    0.150950
# 110            AppliancesEnergy       1-NN-DTWD    6.036547
# 111          BeijingPM10Quality       1-NN-DTWD  139.134908
# 112          BeijingPM25Quality       1-NN-DTWD   88.256082
# 113        BenzeneConcentration       1-NN-DTWD    4.983578
# 114                 Covid3Month       1-NN-DTWD    0.052735
# 115              FloodModeling1       1-NN-DTWD    0.011689
# 116              FloodModeling2       1-NN-DTWD    0.016356
# 117  HouseholdPowerConsumption1       1-NN-DTWD  427.043110
# 118  HouseholdPowerConsumption2       1-NN-DTWD   58.802634
# 119                     IEEEPPG       1-NN-DTWD   37.140393
# 120          NewsTitleSentiment       1-NN-DTWD    0.187257
# 121            AppliancesEnergy       5-NN-DTWD    4.019873
# 122          BeijingPM10Quality       5-NN-DTWD  115.502744
# 123          BeijingPM25Quality       5-NN-DTWD   72.717689
# 124        BenzeneConcentration       5-NN-DTWD    4.868465
# 125                 Covid3Month       5-NN-DTWD    0.042943
# 126              FloodModeling1       5-NN-DTWD    0.009801
# 127              FloodModeling2       5-NN-DTWD    0.016238
# 128  HouseholdPowerConsumption1       5-NN-DTWD  297.221675
# 129  HouseholdPowerConsumption2       5-NN-DTWD   51.494969
# 130                     IEEEPPG       5-NN-DTWD   33.572786
# 131          NewsTitleSentiment       5-NN-DTWD    0.150564
# 132            AppliancesEnergy          Rocket    2.299031
# 133          BeijingPM10Quality          Rocket  120.057765
# 134          BeijingPM25Quality          Rocket   62.769655
# 135        BenzeneConcentration          Rocket    3.360614
# 136                 Covid3Month          Rocket    0.043878
# 137              FloodModeling1          Rocket    0.002356
# 138              FloodModeling2          Rocket    0.005881
# 139  HouseholdPowerConsumption1          Rocket  132.798779
# 140  HouseholdPowerConsumption2          Rocket   32.607104
# 141                     IEEEPPG          Rocket   36.515489
# 142          NewsTitleSentiment          Rocket    0.138059
# 143            AppliancesEnergy             FCN    2.865684
# 144          BeijingPM10Quality             FCN   94.348729
# 145          BeijingPM25Quality             FCN   59.726847
# 146        BenzeneConcentration             FCN    4.988295
# 147                 Covid3Month             FCN    0.074340
# 148              FloodModeling1             FCN    0.006709
# 149              FloodModeling2             FCN    0.006719
# 150  HouseholdPowerConsumption1             FCN  162.244492
# 151  HouseholdPowerConsumption2             FCN   46.829256
# 152                     IEEEPPG             FCN   34.325728
# 153          NewsTitleSentiment             FCN    0.138082
# 154            AppliancesEnergy          ResNet    3.065047
# 155          BeijingPM10Quality          ResNet   95.489374
# 156          BeijingPM25Quality          ResNet   64.462746
# 157        BenzeneConcentration          ResNet    4.061261
# 158                 Covid3Month          ResNet    0.095338
# 159              FloodModeling1          ResNet    0.008868
# 160              FloodModeling2          ResNet    0.013939
# 161  HouseholdPowerConsumption1          ResNet  193.207281
# 162  HouseholdPowerConsumption2          ResNet   39.080121
# 163                     IEEEPPG          ResNet   33.150985
# 164          NewsTitleSentiment          ResNet    0.138295
# 165            AppliancesEnergy       Inception    4.435330
# 166          BeijingPM10Quality       Inception   96.749997
# 167          BeijingPM25Quality       Inception   62.227924
# 168        BenzeneConcentration       Inception    1.584852
# 169                 Covid3Month       Inception    0.053769
# 170              FloodModeling1       Inception    0.017430
# 171              FloodModeling2       Inception    0.007290
# 172  HouseholdPowerConsumption1       Inception  153.716402
# 173  HouseholdPowerConsumption2       Inception   39.409826
# 174                     IEEEPPG       Inception   23.903929
# 175          NewsTitleSentiment       Inception    0.158558

# %%
do_ranking(melted_df=melted_df.copy())
# Out:
# Classifier Names: ['Rocket', 'AutoGluon', 'FCN', 'XGBoost', 'FLAML', 'Random Forest', 'ResNet', 'Inception', 'FPCR', 'FPCR-Bspline', '5-NN-DTWD', '5-NN-ED', 'SVR Optimised', 'SVR', '1-NN-DTWD', '1-NN-ED']
# Average Ranks: [4.454545454545454, 5.7272727272727275, 6.090909090909091, 6.090909090909091, 6.2272727272727275, 6.636363636363637, 6.7272727272727275, 6.818181818181818, 9.090909090909092, 9.318181818181818, 9.363636363636363, 10.545454545454545, 10.954545454545455, 12.409090909090908, 12.545454545454545, 13.0]
#    classifier_name       rank
# 0           Rocket   4.454545
# 1        AutoGluon   5.727273
# 2              FCN   6.090909
# 3          XGBoost   6.090909
# 4            FLAML   6.227273
# 5    Random Forest   6.636364
# 6           ResNet   6.727273
# 7        Inception   6.818182
# 8             FPCR   9.090909
# 9     FPCR-Bspline   9.318182
# 10       5-NN-DTWD   9.363636
# 11         5-NN-ED  10.545455
# 12   SVR Optimised  10.954545
# 13             SVR  12.409091
# 14       1-NN-DTWD  12.545455
# 15         1-NN-ED  13.000000

# %%
# Create DataFrame

# Define a function to compute ranks with average ranking for ties
def rank_accuracies(group):
    # Sort by accuracy
    sorted_group = group.sort_values('accuracy')
    # Compute ranks
    sorted_group['rank'] = sorted_group['accuracy'].rank(method='average')
    return sorted_group

# Apply ranking within each dataset_name
ranked_df = melted_df.groupby('dataset_name').apply(rank_accuracies).reset_index(drop=True)

# Display the ranked DataFrame
print(ranked_df)
# Out:
#                    dataset_name classifier_name    accuracy  rank
# 0              AppliancesEnergy       AutoGluon    2.155978   1.0
# 1              AppliancesEnergy          Rocket    2.299031   2.0
# 2              AppliancesEnergy           FLAML    2.516904   3.0
# 3              AppliancesEnergy             FCN    2.865684   4.0
# 4              AppliancesEnergy          ResNet    3.065047   5.0
# 5              AppliancesEnergy   SVR Optimised    3.454574   6.0
# 6              AppliancesEnergy   Random Forest    3.455120   7.0
# 7              AppliancesEnergy             SVR    3.457631   8.0
# 8              AppliancesEnergy         XGBoost    3.489024   9.0
# 9              AppliancesEnergy       5-NN-DTWD    4.019873  10.0
# 10             AppliancesEnergy         5-NN-ED    4.227438  11.0
# 11             AppliancesEnergy       Inception    4.435330  12.0
# 12             AppliancesEnergy         1-NN-ED    5.231953  13.0
# 13             AppliancesEnergy            FPCR    5.405052  14.5
# 14             AppliancesEnergy    FPCR-Bspline    5.405052  14.5
# 15             AppliancesEnergy       1-NN-DTWD    6.036547  16.0
# 16           BeijingPM10Quality         XGBoost   93.138127   1.0
# 17           BeijingPM10Quality   Random Forest   94.072344   2.0
# 18           BeijingPM10Quality             FCN   94.348729   3.0
# 19           BeijingPM10Quality          ResNet   95.489374   4.0
# 20           BeijingPM10Quality       Inception   96.749997   5.0
# 21           BeijingPM10Quality            FPCR   99.725946   6.0
# 22           BeijingPM10Quality    FPCR-Bspline   99.732125   7.0
# 23           BeijingPM10Quality       AutoGluon  108.381598   8.5
# 24           BeijingPM10Quality           FLAML  108.381598   8.5
# 25           BeijingPM10Quality             SVR  110.574226  10.5
# 26           BeijingPM10Quality   SVR Optimised  110.574226  10.5
# 27           BeijingPM10Quality       5-NN-DTWD  115.502744  12.0
# 28           BeijingPM10Quality         5-NN-ED  115.669411  13.0
# 29           BeijingPM10Quality          Rocket  120.057765  14.0
# 30           BeijingPM10Quality       1-NN-DTWD  139.134908  15.0
# 31           BeijingPM10Quality         1-NN-ED  139.229790  16.0
# 32           BeijingPM25Quality         XGBoost   59.495865   1.0
# 33           BeijingPM25Quality             FCN   59.726847   2.0
# 34           BeijingPM25Quality       Inception   62.227924   3.0
# 35           BeijingPM25Quality          Rocket   62.769655   4.0
# 36           BeijingPM25Quality   Random Forest   63.301428   5.0
# 37           BeijingPM25Quality          ResNet   64.462746   6.0
# 38           BeijingPM25Quality    FPCR-Bspline   69.369892   7.0
# 39           BeijingPM25Quality            FPCR   69.379217   8.0
# 40           BeijingPM25Quality   SVR Optimised   71.437076   9.0
# 41           BeijingPM25Quality       5-NN-DTWD   72.717689  10.0
# 42           BeijingPM25Quality         5-NN-ED   74.156382  11.0
# 43           BeijingPM25Quality       AutoGluon   75.187533  12.0
# 44           BeijingPM25Quality             SVR   75.734162  13.0
# 45           BeijingPM25Quality           FLAML   76.546076  14.0
# 46           BeijingPM25Quality         1-NN-ED   88.193545  15.0
# 47           BeijingPM25Quality       1-NN-DTWD   88.256082  16.0
# 48         BenzeneConcentration         XGBoost    0.637726   1.0
# 49         BenzeneConcentration   Random Forest    0.855559   2.0
# 50         BenzeneConcentration       Inception    1.584852   3.0
# 51         BenzeneConcentration          Rocket    3.360614   4.0
# 52         BenzeneConcentration       AutoGluon    3.874767   5.0
# 53         BenzeneConcentration           FLAML    4.001022   6.0
# 54         BenzeneConcentration          ResNet    4.061261   7.0
# 55         BenzeneConcentration             SVR    4.790901   8.5
# 56         BenzeneConcentration   SVR Optimised    4.790901   8.5
# 57         BenzeneConcentration       5-NN-DTWD    4.868465  10.0
# 58         BenzeneConcentration       1-NN-DTWD    4.983578  11.0
# 59         BenzeneConcentration             FCN    4.988295  12.0
# 60         BenzeneConcentration         5-NN-ED    5.844980  13.0
# 61         BenzeneConcentration         1-NN-ED    6.535685  14.0
# 62         BenzeneConcentration            FPCR   11.088396  15.0
# 63         BenzeneConcentration    FPCR-Bspline   11.094974  16.0
# 64                  Covid3Month       AutoGluon    0.040439   1.0
# 65                  Covid3Month         5-NN-ED    0.041815   2.0
# 66                  Covid3Month   Random Forest    0.042400   3.0
# 67                  Covid3Month       5-NN-DTWD    0.042943   4.0
# 68                  Covid3Month           FLAML    0.043481   5.0
# 69                  Covid3Month          Rocket    0.043878   6.0
# 70                  Covid3Month         XGBoost    0.044682   7.0
# 71                  Covid3Month            FPCR    0.044912   8.5
# 72                  Covid3Month    FPCR-Bspline    0.044912   8.5
# 73                  Covid3Month       1-NN-DTWD    0.052735  10.0
# 74                  Covid3Month         1-NN-ED    0.053060  11.0
# 75                  Covid3Month       Inception    0.053769  12.0
# 76                  Covid3Month             SVR    0.065840  13.5
# 77                  Covid3Month   SVR Optimised    0.065840  13.5
# 78                  Covid3Month             FCN    0.074340  15.0
# 79                  Covid3Month          ResNet    0.095338  16.0
# 80               FloodModeling1          Rocket    0.002356   1.0
# 81               FloodModeling1             FCN    0.006709   2.0
# 82               FloodModeling1          ResNet    0.008868   3.0
# 83               FloodModeling1       5-NN-DTWD    0.009801   4.0
# 84               FloodModeling1       1-NN-DTWD    0.011689   5.0
# 85               FloodModeling1       AutoGluon    0.013680   6.0
# 86               FloodModeling1         1-NN-ED    0.014820   7.0
# 87               FloodModeling1   Random Forest    0.015891   8.0
# 88               FloodModeling1         XGBoost    0.015971   9.0
# 89               FloodModeling1         5-NN-ED    0.016193  10.0
# 90               FloodModeling1           FLAML    0.016977  11.0
# 91               FloodModeling1       Inception    0.017430  12.0
# 92               FloodModeling1            FPCR    0.018853  13.5
# 93               FloodModeling1    FPCR-Bspline    0.018853  13.5
# 94               FloodModeling1   SVR Optimised    0.046304  15.0
# 95               FloodModeling1             SVR    0.077897  16.0
# 96               FloodModeling2          Rocket    0.005881   1.0
# 97               FloodModeling2             FCN    0.006719   2.0
# 98               FloodModeling2       Inception    0.007290   3.0
# 99               FloodModeling2           FLAML    0.009305   4.0
# 100              FloodModeling2          ResNet    0.013939   5.0
# 101              FloodModeling2   Random Forest    0.014095   6.0
# 102              FloodModeling2       5-NN-DTWD    0.016238   7.0
# 103              FloodModeling2       1-NN-DTWD    0.016356   8.0
# 104              FloodModeling2         XGBoost    0.018199   9.0
# 105              FloodModeling2         1-NN-ED    0.018552  10.0
# 106              FloodModeling2         5-NN-ED    0.018586  11.0
# 107              FloodModeling2       AutoGluon    0.019079  13.0
# 108              FloodModeling2            FPCR    0.019079  13.0
# 109              FloodModeling2    FPCR-Bspline    0.019079  13.0
# 110              FloodModeling2             SVR    0.075804  15.5
# 111              FloodModeling2   SVR Optimised    0.075804  15.5
# 112  HouseholdPowerConsumption1          Rocket  132.798779   1.0
# 113  HouseholdPowerConsumption1       AutoGluon  145.957598   2.0
# 114  HouseholdPowerConsumption1            FPCR  147.548998   3.0
# 115  HouseholdPowerConsumption1    FPCR-Bspline  147.549200   4.0
# 116  HouseholdPowerConsumption1   SVR Optimised  152.391358   5.0
# 117  HouseholdPowerConsumption1       Inception  153.716402   6.0
# 118  HouseholdPowerConsumption1             FCN  162.244492   7.0
# 119  HouseholdPowerConsumption1           FLAML  169.335060   8.0
# 120  HouseholdPowerConsumption1          ResNet  193.207281   9.0
# 121  HouseholdPowerConsumption1         XGBoost  231.089829  10.0
# 122  HouseholdPowerConsumption1   Random Forest  248.858964  11.0
# 123  HouseholdPowerConsumption1       5-NN-DTWD  297.221675  12.0
# 124  HouseholdPowerConsumption1       1-NN-DTWD  427.043110  13.0
# 125  HouseholdPowerConsumption1         5-NN-ED  432.594707  14.0
# 126  HouseholdPowerConsumption1         1-NN-ED  473.932736  15.0
# 127  HouseholdPowerConsumption1             SVR  519.155544  16.0
# 128  HouseholdPowerConsumption2          Rocket   32.607104   1.0
# 129  HouseholdPowerConsumption2           FLAML   37.031474   2.0
# 130  HouseholdPowerConsumption2          ResNet   39.080121   3.0
# 131  HouseholdPowerConsumption2       Inception   39.409826   4.0
# 132  HouseholdPowerConsumption2         XGBoost   44.372933   5.0
# 133  HouseholdPowerConsumption2             FCN   46.829256   6.0
# 134  HouseholdPowerConsumption2       AutoGluon   46.925185   7.5
# 135  HouseholdPowerConsumption2            FPCR   46.925185   7.5
# 136  HouseholdPowerConsumption2    FPCR-Bspline   46.929783   9.0
# 137  HouseholdPowerConsumption2   Random Forest   46.932139  10.0
# 138  HouseholdPowerConsumption2       5-NN-DTWD   51.494969  11.0
# 139  HouseholdPowerConsumption2   SVR Optimised   55.980830  12.0
# 140  HouseholdPowerConsumption2             SVR   57.339837  13.0
# 141  HouseholdPowerConsumption2       1-NN-DTWD   58.802634  14.0
# 142  HouseholdPowerConsumption2         5-NN-ED   64.272956  15.0
# 143  HouseholdPowerConsumption2         1-NN-ED   71.479369  16.0
# 144                     IEEEPPG       Inception   23.903929   1.0
# 145                     IEEEPPG       AutoGluon   25.574776   2.0
# 146                     IEEEPPG         5-NN-ED   27.111213   3.0
# 147                     IEEEPPG           FLAML   27.603676   4.0
# 148                     IEEEPPG    FPCR-Bspline   31.381212   5.0
# 149                     IEEEPPG            FPCR   31.381214   6.0
# 150                     IEEEPPG         XGBoost   31.487901   7.0
# 151                     IEEEPPG   Random Forest   32.109070   8.0
# 152                     IEEEPPG          ResNet   33.150985   9.0
# 153                     IEEEPPG         1-NN-ED   33.208862  10.0
# 154                     IEEEPPG       5-NN-DTWD   33.572786  11.0
# 155                     IEEEPPG             FCN   34.325728  12.0
# 156                     IEEEPPG             SVR   36.301933  13.0
# 157                     IEEEPPG          Rocket   36.515489  14.0
# 158                     IEEEPPG       1-NN-DTWD   37.140393  15.0
# 159                     IEEEPPG   SVR Optimised   37.254146  16.0
# 160          NewsTitleSentiment          Rocket    0.138059   1.0
# 161          NewsTitleSentiment             FCN    0.138082   2.0
# 162          NewsTitleSentiment           FLAML    0.138103   3.0
# 163          NewsTitleSentiment       AutoGluon    0.138126   5.0
# 164          NewsTitleSentiment            FPCR    0.138126   5.0
# 165          NewsTitleSentiment    FPCR-Bspline    0.138126   5.0
# 166          NewsTitleSentiment          ResNet    0.138295   7.0
# 167          NewsTitleSentiment         XGBoost    0.138336   8.0
# 168          NewsTitleSentiment             SVR    0.138881   9.5
# 169          NewsTitleSentiment   SVR Optimised    0.138881   9.5
# 170          NewsTitleSentiment   Random Forest    0.143103  11.0
# 171          NewsTitleSentiment       5-NN-DTWD    0.150564  12.0
# 172          NewsTitleSentiment         5-NN-ED    0.150950  13.0
# 173          NewsTitleSentiment       Inception    0.158558  14.0
# 174          NewsTitleSentiment       1-NN-DTWD    0.187257  15.0
# 175          NewsTitleSentiment         1-NN-ED    0.193318  16.0

# %%
# Compute average rank per classifier
average_rank_per_classifier = ranked_df.groupby('classifier_name')['rank'].mean().reset_index()
average_rank_per_classifier = average_rank_per_classifier.sort_values(by='rank', ascending=True).reset_index(drop=True)

# Extract lists
classifier_names = average_rank_per_classifier['classifier_name'].tolist()
average_ranks = average_rank_per_classifier['rank'].tolist()

# Display the lists
print("Classifier Names:", classifier_names)
print("Average Ranks:", average_ranks)

# Sort by average rank in descending order


average_rank_per_classifier
# Out:
# Classifier Names: ['Rocket', 'AutoGluon', 'FCN', 'XGBoost', 'FLAML', 'Random Forest', 'ResNet', 'Inception', 'FPCR', 'FPCR-Bspline', '5-NN-DTWD', '5-NN-ED', 'SVR Optimised', 'SVR', '1-NN-DTWD', '1-NN-ED']
# Average Ranks: [4.454545454545454, 5.7272727272727275, 6.090909090909091, 6.090909090909091, 6.2272727272727275, 6.636363636363637, 6.7272727272727275, 6.818181818181818, 9.090909090909092, 9.318181818181818, 9.363636363636363, 10.545454545454545, 10.954545454545455, 12.409090909090908, 12.545454545454545, 13.0]
#    classifier_name       rank
# 0           Rocket   4.454545
# 1        AutoGluon   5.727273
# 2              FCN   6.090909
# 3          XGBoost   6.090909
# 4            FLAML   6.227273
# 5    Random Forest   6.636364
# 6           ResNet   6.727273
# 7        Inception   6.818182
# 8             FPCR   9.090909
# 9     FPCR-Bspline   9.318182
# 10       5-NN-DTWD   9.363636
# 11         5-NN-ED  10.545455
# 12   SVR Optimised  10.954545
# 13             SVR  12.409091
# 14       1-NN-DTWD  12.545455
# 15         1-NN-ED  13.000000
